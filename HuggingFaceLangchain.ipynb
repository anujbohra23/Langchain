# %%
# !pip install langchain-huggingface
# !pip install huggingface-hub
# !pip install transformers
# !pip install accelerate
# !pip install bitsandbytes
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.4/337.4 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 4.2 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...

# %%
# Import necessary libraries
from langchain_huggingface import HuggingFaceEndpoint
from huggingface_hub import notebook_login
from google.colab import userdata
import os
from langchain import PromptTemplate, LLMChain

# Authenticate with Hugging Face
# notebook_login()

# Retrieve token from userdata
anuj_tokenkey = userdata.get("Langchain")

# Verify token retrieval
if not anuj_tokenkey:
    raise ValueError("Hugging Face token not found. Please set the 'Langchain' key in userdata.")

# Set the token as an environment variable
os.environ["HUGGINGFACEHUB_API_TOKEN"] = anuj_tokenkey

# Define the repository ID
repo_id = "mistralai/Mistral-7B-Instruct-v0.3"

# Initialize the HuggingFaceEndpoint
llm = HuggingFaceEndpoint(
    repo_id=repo_id,
    max_length=128,
    temperature=0.7,
    token=anuj_tokenkey
)

# Verify the initialization
print(llm)

# Invoke the model with a test query
response = llm.invoke("What is machine learning?")
print(response)

# Define the prompt template
question = "Who won the Cricket World Cup in the year 2011?"
template = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question"])

# Verify the prompt
print(prompt)

# Initialize the LLMChain
llm_chain = LLMChain(llm=llm, prompt=prompt)

# Invoke the LLMChain with the question
response = llm_chain.invoke(question)
print(response)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.

# %%
# from google.colab import userdata
# sec_key = userdata.get("HF_TOKEN")
# print(sec_key)

# %%
#HuggingFace Endpoint - for calling models using api
# from langchain_huggingface import HuggingFaceEndpoint
# from huggingface_hub import notebook_login
# notebook_login()

# %%
# from google.colab import userdata
# anuj_tokenkey = userdata.get("Langchain")
# print(anuj_tokenkey)

# %%
# import os
# os.environ["Langchain"] = anuj_tokenkey

# %%
# repo_id = "mistralai/Mistral-7B-Instruct-v0.3"
# llm = HuggingFaceEndpoint(repo_id = repo_id, max_length = 128, temperature = 0.7, token = anuj_tokenkey)

# %%
# llm

# %%
#llm.invoke - used to use the model
# llm.invoke("what is machine learning")

# %%
# from langchain import PromptTemplate, LLMChain

# question="Who won the Cricket World Cup in the year 2011?"
# template = """Question: {question}
# Answer: Let's think step by step."""
# prompt = PromptTemplate(template=template, input_variables=["question"])
# print(prompt)

# %%
# llm_chain=LLMChain(llm=llm,prompt=prompt)
# print(llm_chain.invoke(question))

# %% [markdown]
# HuggingFace Pipeline

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %%
model_id="gpt2"
model=AutoModelForCausalLM.from_pretrained(model_id)
tokenizer=AutoTokenizer.from_pretrained(model_id)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
pipe=pipeline("text-generation",model=model,tokenizer=tokenizer,max_new_tokens=100)
hf=HuggingFacePipeline(pipeline=pipe)

# %%
hf
# Out:
# HuggingFacePipeline(pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x7eef3a422f20>)

# %%
hf.invoke("What is machine learning")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# "What is machine learning and what is it?\n\nMachine learning is a mathematical technique that shows how computers learn anything from words and pictures, to code or numbers, and how a computer makes decisions:\n\nWhat a computer makes by making a decision\n\nIs information being added to a user's memory at will? - If a computer makes a decision based on the information that the user has to input, then it must act on information from that information to create that choice.\n\nHow does the data get into"

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.device_count())

# %%
gpu_llm = HuggingFacePipeline.from_model_id(
    model_id="gpt2",
    task="text-generation",
    device_map="auto",  # Automatically sets device
    pipeline_kwargs={"max_new_tokens": 100},
)

# %%
from langchain_core.prompts import PromptTemplate

template = """Question: {question}

Answer: Let's think step by step."""
prompt = PromptTemplate.from_template(template)

# %%
chain=prompt|gpu_llm

# %%
question="What is artificial intelligence?"
chain.invoke({"question":question})
# Out:
# "Question: What is artificial intelligence?\n\nAnswer: Let's think step by step. An artificial intelligence program can't be the only computer in the universe, nor could it be an efficient tool used only by an intelligence program. We are only talking about the number of machines on many planets. A system could not be the only algorithm generating a new value, yet it was always created in a different way than our own system could be and was always better.\n\nI'll stop here, but my first post in this series will be on AI: Myths and Misconceptions,"
